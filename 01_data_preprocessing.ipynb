# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("NYC_TLC_Messy.csv")
print(df)
# Out:
#           TripID  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0       24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1       35634249         1          04/11/17 14:53          04/11/17 15:19
# 2      106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3       38942136         2          05/07/17 13:17          05/07/17 13:48
# 4       30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# ...          ...       ...                     ...                     ...
# 22894   47368116         1   06/29/2017 7:30:30 PM   06/29/2017 7:43:29 PM
# 22895   84575569         2          10/08/17 02:24          10/08/17 02:59
# 22896   98456136         1   11/20/2017 9:59:41 AM  11/20/2017 10:07:39 AM
# 22897   36424085         2  04/29/2017 11:05:05 PM  04/29/2017 11:18:14 PM
# 22898   15752972         2   02/27/2017 8:24:37 AM   02/27/2017 8:33:42 AM
#
# ...

# %%
print(df.columns)
# Out:
# Index(['TripID', 'VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# TripID                     0
# VendorID                   0
# tpep_pickup_datetime       0
# tpep_dropoff_datetime      0
# passenger_count          458
# trip_distance              0
# RatecodeID                 0
# store_and_fwd_flag         0
# PULocationID               0
# DOLocationID               0
# payment_type               0
# fare_amount              688
# extra                      0
# mta_tax                    0
# tip_amount                 0
# tolls_amount               0
# improvement_surcharge      0
# total_amount               0
# dtype: int64

# %%
print(df['passenger_count'].isnull().sum())
print(df['passenger_count'].head(6))
# Out:
# 458
# 0    6.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    NaN
# 5    6.0
# Name: passenger_count, dtype: float64

# %%
df['passenger_count']=df['passenger_count'].fillna(df['passenger_count'].median())

# %%
print(df['passenger_count'].isnull().sum())
# Out:
# 0

# %%
print(df['passenger_count'].head(6))
# Out:
# 0    6.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# 5    6.0
# Name: passenger_count, dtype: float64

# %%
print(df['fare_amount'].isnull().sum())
# Out:
# 688

# %%
df['fare_amount']=df['fare_amount'].fillna(df['fare_amount'].median())
print(df['fare_amount'].isnull().sum())
# Out:
# 0

# %%
print(df.isnull().sum())
# Out:
# TripID                   0
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
print(df['TripID'].min())
print(df['TripID'].max())
print(df['TripID'].value_counts())
# Out:
# 12127
# 113486300
# TripID
# 43550932     2
# 95049490     2
# 7175550      2
# 47927710     2
# 37705705     2
#             ..
# 107120719    1
# 49074494     1
# 25867855     1
# 105261930    1
# 28736913     1
# Name: count, Length: 22699, dtype: int64

# %%
print(df['VendorID'].min())
print(df['VendorID'].max())
print(df['VendorID'].value_counts())
# Out:
# 1
# 2
# VendorID
# 2    12732
# 1    10167
# Name: count, dtype: int64

# %%
print("minimun no.of passengers are:",df['passenger_count'].min())
print("maximum no.of passengers are:",df['passenger_count'].max())
print(df['passenger_count'].value_counts())
# Out:
# minimun no.of passengers are: -2.0
# maximum no.of passengers are: 6.0
# passenger_count
#  1.0    16359
#  2.0     3281
#  5.0     1121
#  3.0      938
#  6.0      686
#  4.0      452
#  0.0       32
# -2.0       30
# Name: count, dtype: int64

# %%
print(df.shape)
# Out:
# (22899, 18)

# %%
df=df[(df['passenger_count']>=1)&(df['passenger_count']<=6)]

# %%
print(df.shape)
# Out:
# (22837, 18)

# %%
print(df['trip_distance'].min())
print(df['trip_distance'].max())
print(df['trip_distance'].value_counts())
# Out:
# 0.0
# 500.0
# trip_distance
# 1.00     532
# 0.90     508
# 0.80     500
# 1.10     494
# 0.70     472
#         ...
# 12.03      1
# 15.26      1
# 6.07       1
# 12.85      1
# 19.07      1
# Name: count, Length: 1544, dtype: int64

# %%
print((df['trip_distance']==0).sum())
# Out:
# 152

# %%
df=df[(df['trip_distance']>0)]
print((df['trip_distance']==0).sum())
print(df.shape)
# Out:
# 0
# (22685, 18)

# %%
print(df['RatecodeID'].value_counts())
# Out:
# RatecodeID
# 1    22106
# 2      497
# 3       38
# 5       36
# 4        8
# Name: count, dtype: int64

# %%
print(df['fare_amount'].min())
print(df['fare_amount'].max())
print(df['fare_amount'].value_counts())
# Out:
# -120.0
# 9999.0
# fare_amount
# 9.5     1517
# 6.0     1123
# 5.5     1058
# 6.5     1053
# 7.0     1036
#         ...
# 79.5       1
# 90.5       1
# 54.5       1
# 73.5       1
# 94.2       1
# Name: count, Length: 175, dtype: int64

# %%
df=df[(df['fare_amount']>0)]
print(df.shape)
# Out:
# (22668, 18)

# %%
print(df['total_amount'].min())
print(df['total_amount'].max())
print(df['total_amount'].value_counts())
# Out:
# 3.3
# 1200.29
# total_amount
# 7.30     545
# 7.80     529
# 6.80     524
# 8.30     521
# 8.80     497
#         ...
# 13.44      1
# 36.08      1
# 62.16      1
# 35.00      1
# 6.55       1
# Name: count, Length: 1334, dtype: int64

# %%
print("minimum value of extra fee:",df['extra'].min())
print("minimum value of mta_tax:",df['mta_tax'].min())
print("minimum value of tip_amount:",df['tip_amount'].min())
print("minimum value of tolls_amount:",df['tolls_amount'].min())
print("minimum value of improvemnet_surcharge:",df['improvement_surcharge'].min())
# Out:
# minimum value of extra fee: 0.0
# minimum value of mta_tax: 0.0
# minimum value of tip_amount: 0.0
# minimum value of tolls_amount: 0.0
# minimum value of improvemnet_surcharge: 0.3

# %%
print(df[['tpep_pickup_datetime','tpep_dropoff_datetime']].isna().sum())
# Out:
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# dtype: int64

# %%
df['tpep_pickup_datetime']=pd.to_datetime(df['tpep_pickup_datetime'],errors='coerce')
df['tpep_dropoff_datetime']=pd.to_datetime(df['tpep_dropoff_datetime'],errors='coerce')

# %%
df['trip_duration_minutes']=(df['tpep_dropoff_datetime']-df['tpep_pickup_datetime']).dt.total_seconds()/60

# %%
df=df.dropna(subset=['tpep_pickup_datetime','tpep_dropoff_datetime'])
print(df.shape)
# Out:
# (13669, 19)

# %%
df[['tpep_pickup_datetime','tpep_dropoff_datetime']].dtypes
# Out:
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# dtype: object

# %%
df['trip_duration_minutes']=(df['tpep_dropoff_datetime']-df['tpep_pickup_datetime']).dt.total_seconds()/60

# %%
print(df['trip_duration_minutes'])
# Out:
# 0        14.066667
# 2         7.200000
# 4        16.716667
# 5         8.000000
# 7        21.983333
#            ...
# 22890    21.783333
# 22891    10.533333
# 22896     7.966667
# 22897    13.150000
# 22898     9.083333
# Name: trip_duration_minutes, Length: 13669, dtype: float64

# %%
df=df[df['trip_duration_minutes']>1]
print(df.shape)
# Out:
# (13618, 19)

# %%
df.duplicated().sum()
# Out:
# np.int64(123)

# %%
df=df.drop_duplicates()
print(df.shape)
# Out:
# (13495, 19)

# %%
zone=pd.read_csv("taxi_zone_lookup.csv")

# %%
df=df.merge(zone[['LocationID','Borough','Zone']],
             left_on='PULocationID',
             right_on='LocationID',
             how='left')

# %%
df.rename(columns={'Borough':'DO_Borough','Zone':'DO_Zone'},inplace=True)

# %%
df=df.merge(zone[['LocationID','Borough','Zone']],
             how='left',
             left_on='DOLocationID',
             right_on='LocationID')

# %%
df.rename(columns={'Borough':'PU_Borough','Zone':'PU_Zone'},inplace=True)
df.drop('LocationID_y',axis=1,inplace=True)

# %%
df.drop(['PULocationID','DOLocationID'],axis=1,inplace=True)

# %%
df
# Out:
#           TripID  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0       24870114         2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1      106203690         1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 2       30841670         2  2017-04-15 23:32:20   2017-04-15 23:49:03
# 3       23345809         2  2017-03-25 20:34:11   2017-03-25 20:42:11
# 4       69059411         2  2017-08-15 17:41:06   2017-08-15 18:03:05
# ...          ...       ...                  ...                   ...
# 13490   80420727         1  2017-09-24 18:14:04   2017-09-24 18:22:36
# 13491   44531431         2  2017-05-24 10:13:43   2017-05-24 10:31:34
# 13492   69393675         2  2017-08-16 20:17:35   2017-08-16 20:25:48
# 13493   81511935         2  2017-09-28 11:36:30   2017-09-28 11:49:58
# 13494   63965316         2  2017-07-28 07:12:44   2017-07-28 07:31:39
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# ...

# %%
df.isnull().sum()
# Out:
# TripID                     0
# VendorID                   0
# tpep_pickup_datetime       0
# tpep_dropoff_datetime      0
# passenger_count            0
# trip_distance              0
# RatecodeID                 0
# store_and_fwd_flag         0
# payment_type               0
# fare_amount                0
# extra                      0
# mta_tax                    0
# tip_amount                 0
# tolls_amount               0
# improvement_surcharge      0
# total_amount               0
# trip_duration_minutes      0
# LocationID_x               0
# DO_Borough                 3
# DO_Zone                  183
# PU_Borough                36
# PU_Zone                  156
# dtype: int64

# %%
df['DO_Borough'].fillna('unknown',inplace=True)
df['DO_Zone'].fillna('unknown',inplace=True)
df['PU_Borough'].fillna('unknown',inplace=True)
df['PU_Zone'].fillna('unknown',inplace=True)
# Out:
# /tmp/ipykernel_4469/286710025.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DO_Borough'].fillna('unknown',inplace=True)
# /tmp/ipykernel_4469/286710025.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum()
# Out:
# TripID                   0
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# trip_duration_minutes    0
# LocationID_x             0
# DO_Borough               0
# DO_Zone                  0
# PU_Borough               0
# PU_Zone                  0
# dtype: int64

# %%
print("do_borough:",df['DO_Borough'].unique())
print("do_zone:",df['DO_Zone'].unique())
print("pu_borough:",df['PU_Borough'].unique())
print("pu_zone:",df['PU_Zone'].unique())
# Out:
# do_borough: ['Manhattan' 'Queens' 'Brooklyn' 'Unknown' 'unknown' 'Bronx'
#  'Staten Island']
# do_zone: ['Garment District' 'Yorkville East' 'Alphabet City' 'Midtown Center'
#  'Upper East Side South' 'Upper West Side North' 'Midtown North'
#  'Morningside Heights' 'Midtown East' 'Central Park' 'JFK Airport'
#  'Times Sq/Theatre District' 'Lincoln Square East' 'Lenox Hill East'
#  'Flatiron' 'Murray Hill' 'Union Sq' 'West Village'
#  'Upper West Side South' 'West Chelsea/Hudson Yards' 'Yorkville West'
#  'Manhattan Valley' 'LaGuardia Airport' 'Upper East Side North'
#  'East Chelsea' 'Gramercy' 'Clinton East' 'East Village'
#  'Greenwich Village South' 'Financial District North' 'Hudson Sq'
#  'Penn Station/Madison Sq West' 'Greenwich Village North'
#  'Williamsburg (South Side)' 'TriBeCa/Civic Center' 'UN/Turtle Bay South'
#  'East Harlem South' 'East Harlem North' 'Meatpacking/West Village West'
#  'Sutton Place/Turtle Bay North' 'Lower East Side' 'Clinton West'
# ...

# %%
df['VendorID']=df['VendorID'].astype('category')
df['RatecodeID']=df['RatecodeID'].astype('category')
df['payment_type']=df['payment_type'].astype('category')
df['VendorID']=df['VendorID'].astype('category')

# %%
df.dtypes
# Out:
# TripID                            int64
# VendorID                       category
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                     category
# store_and_fwd_flag               object
# payment_type                   category
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# trip_duration_minutes           float64
# LocationID_x                      int64
# DO_Borough                       object
# DO_Zone                          object
# PU_Borough                       object
# PU_Zone                          object
# dtype: object

# %%
df['store_and_fwd_flag']=df['store_and_fwd_flag'].astype(str)
df['passenger_count']=df['passenger_count'].astype(int)

# %%
df.dtypes
# Out:
# TripID                            int64
# VendorID                       category
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# RatecodeID                     category
# store_and_fwd_flag               object
# payment_type                   category
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# trip_duration_minutes           float64
# LocationID_x                      int64
# DO_Borough                       object
# DO_Zone                          object
# PU_Borough                       object
# PU_Zone                          object
# dtype: object

# %%
df['store_and_fwd_flag']=df['store_and_fwd_flag'].map({'N':0,'Y':1})

# %%
print(df)
# Out:
#           TripID VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0       24870114        2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1      106203690        1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 2       30841670        2  2017-04-15 23:32:20   2017-04-15 23:49:03
# 3       23345809        2  2017-03-25 20:34:11   2017-03-25 20:42:11
# 4       69059411        2  2017-08-15 17:41:06   2017-08-15 18:03:05
# ...          ...      ...                  ...                   ...
# 13490   80420727        1  2017-09-24 18:14:04   2017-09-24 18:22:36
# 13491   44531431        2  2017-05-24 10:13:43   2017-05-24 10:31:34
# 13492   69393675        2  2017-08-16 20:17:35   2017-08-16 20:25:48
# 13493   81511935        2  2017-09-28 11:36:30   2017-09-28 11:49:58
# 13494   63965316        2  2017-07-28 07:12:44   2017-07-28 07:31:39
#
#        passenger_count  trip_distance RatecodeID  store_and_fwd_flag  \
# ...

# %%
df['PU_Zone_freq']=df['PU_Zone'].map(df['PU_Zone'].value_counts())
df['DO_Zone_freq']=df['DO_Zone'].map(df['DO_Zone'].value_counts())

# %%
df
# Out:
#           TripID VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0       24870114        2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1      106203690        1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 2       30841670        2  2017-04-15 23:32:20   2017-04-15 23:49:03
# 3       23345809        2  2017-03-25 20:34:11   2017-03-25 20:42:11
# 4       69059411        2  2017-08-15 17:41:06   2017-08-15 18:03:05
# ...          ...      ...                  ...                   ...
# 13490   80420727        1  2017-09-24 18:14:04   2017-09-24 18:22:36
# 13491   44531431        2  2017-05-24 10:13:43   2017-05-24 10:31:34
# 13492   69393675        2  2017-08-16 20:17:35   2017-08-16 20:25:48
# 13493   81511935        2  2017-09-28 11:36:30   2017-09-28 11:49:58
# 13494   63965316        2  2017-07-28 07:12:44   2017-07-28 07:31:39
#
#        passenger_count  trip_distance RatecodeID  store_and_fwd_flag  \
# ...

# %%
df=pd.get_dummies(df,columns=['PU_Borough','DO_Borough'],drop_first=True)

# %%
df
# Out:
#           TripID VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0       24870114        2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1      106203690        1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 2       30841670        2  2017-04-15 23:32:20   2017-04-15 23:49:03
# 3       23345809        2  2017-03-25 20:34:11   2017-03-25 20:42:11
# 4       69059411        2  2017-08-15 17:41:06   2017-08-15 18:03:05
# ...          ...      ...                  ...                   ...
# 13490   80420727        1  2017-09-24 18:14:04   2017-09-24 18:22:36
# 13491   44531431        2  2017-05-24 10:13:43   2017-05-24 10:31:34
# 13492   69393675        2  2017-08-16 20:17:35   2017-08-16 20:25:48
# 13493   81511935        2  2017-09-28 11:36:30   2017-09-28 11:49:58
# 13494   63965316        2  2017-07-28 07:12:44   2017-07-28 07:31:39
#
#        passenger_count  trip_distance RatecodeID  store_and_fwd_flag  \
# ...

# %%
bool_cols=df.select_dtypes(include='bool').columns
for col in bool_cols:
    df[col]=df[col].map({True:1,False:0})

# %%
df
# Out:
#           TripID VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0       24870114        2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1      106203690        1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 2       30841670        2  2017-04-15 23:32:20   2017-04-15 23:49:03
# 3       23345809        2  2017-03-25 20:34:11   2017-03-25 20:42:11
# 4       69059411        2  2017-08-15 17:41:06   2017-08-15 18:03:05
# ...          ...      ...                  ...                   ...
# 13490   80420727        1  2017-09-24 18:14:04   2017-09-24 18:22:36
# 13491   44531431        2  2017-05-24 10:13:43   2017-05-24 10:31:34
# 13492   69393675        2  2017-08-16 20:17:35   2017-08-16 20:25:48
# 13493   81511935        2  2017-09-28 11:36:30   2017-09-28 11:49:58
# 13494   63965316        2  2017-07-28 07:12:44   2017-07-28 07:31:39
#
#        passenger_count  trip_distance RatecodeID  store_and_fwd_flag  \
# ...

# %%
df.to_csv('taxi10.csv',index=False)
